# %% [markdown]
# # Problem statement:
# ### Using ML/DL techniques, match similar products from the Flipkart dataset with the Amazon dataset. Once similar products are matched, display the retail price from FK and AMZ side by side. Please explore as many techniques as possible before choosing the final technique.
# ### You may either display the final result in single table format OR You may create a simple form where we input the product name and the output of prices of the product from both websites are displayed.

# %%
#Basic and most important libraries
import pandas as pd , numpy as np
from sklearn.preprocessing import StandardScaler , MinMaxScaler
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import plotly

# %%
df1=pd.read_csv('amz_com-ecommerce_sample.csv',encoding = 'unicode_escape')
df2=pd.read_csv('flipkart_com-ecommerce_sample.csv',encoding = 'unicode_escape')

# %%
df1.head(5)
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df1.shape
# Out:
# (20000, 15)

# %%
df1['brand'].nunique()
# Out:
# 3499

# %%
df2.head(5)
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df1[['image_1','image_2','image_3','image_4','image_5','image_6','image_7','image_8','image_9','image_10',
    'image_11','image_12','image_13','image_14','image_15','image_16','image_17','image_18','image_19','image_20',
   'image_21','image_22','image_23','image_24','image_25','image_26']]=df1['image'].str.split(",",expand=True)

# %%
df1.shape
# Out:
# (20000, 41)

# %%
df1.head(5)
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df1[['image_1','image_2','image_3']]
# Out:
#                                                  image_1  \
# 0      ["http://img5a.flixcart.com/image/short/u/4/a/...
# 1      ["http://img6a.flixcart.com/image/sofa-bed/j/f...
# 2      ["http://img5a.flixcart.com/image/shoe/7/z/z/r...
# 3      ["http://img5a.flixcart.com/image/short/6/2/h/...
# 4      ["http://img5a.flixcart.com/image/pet-shampoo/...
# ...                                                  ...
# 19995  ["http://img6a.flixcart.com/image/wall-decorat...
# 19996  ["http://img6a.flixcart.com/image/sticker/z/g/...
# 19997  ["http://img5a.flixcart.com/image/sticker/b/s/...
# 19998  ["http://img5a.flixcart.com/image/sticker/4/2/...
# 19999  ["http://img6a.flixcart.com/image/sticker/z/k/...
#
#                                                  image_2  \
# 0       "http://img5a.flixcart.com/image/short/p/j/z/...
# 1       "http://img6a.flixcart.com/image/sofa-bed/j/f...
# 2       "http://img6a.flixcart.com/image/shoe/7/z/z/r...
# ...

# %%
df1.replace({'image_1': {'[': ' '}},
               regex=True)['image_1'].apply(eval)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 df1.replace({'image_1': {'[': ' '}},
#       2                regex=True)['image_1'].apply(eval)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5282, in DataFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    5272 @doc(NDFrame.replace, **_shared_doc_kwargs)
#    5273 def replace(
#    5274     self,
#    (...)
#    5280     method: str | lib.NoDefault = lib.no_default,
#    5281 ):
# -> 5282     return super().replace(
#    5283         to_replace=to_replace,
#    5284         value=value,
#    5285         inplace=inplace,
#    5286         limit=limit,
#    5287         regex=regex,
#    5288         method=method,
#    5289     )
#
# ...

# %%
url=str(df1['image_2'][1])

# %%
url
# Out:
# 'http://img6a.flixcart.com/image/sofa-bed/j/f/y/fhd112-double-foam-fabhomedecor-leatherette-black-leatherette-original-imaeh3gemjjcg9ta.jpeg'

# %%
url=url.replace('"',"")

# %%
urllib.request.urlretrieve(url,'file_name')
# Out:
# ('file_name', <http.client.HTTPMessage at 0x1f565128dc0>)

# %%
img = Image.open('file_name')

img.show()

# %%
import urllib.request
from PIL import Image

urllib.request.urlretrieve("http://img6a.flixcart.com/image/shoe/7/z/z/red-as-454-aw-11-original-imaeebfw2veeuz8s.jpeg",'file_name')
img = Image.open('file_name')

img.show()

# %%
import tensorflow as tf
import tensorflow_hub as hub

model_url = "https://tfhub.dev/tensorflow/efficientnet/lite0/feature-vector/2"

IMAGE_SHAPE = (224, 224)

layer = hub.KerasLayer(model_url, input_shape=IMAGE_SHAPE+(3,))
model = tf.keras.Sequential([layer])

# %%
file = Image.open('file_name').convert('L').resize(IMAGE_SHAPE)  #1
file = np.stack((file,)*3, axis=-1)                       #2
file = np.array(file)/255.0                               #3

embedding = model.predict(file[np.newaxis, ...])
embedding_np = np.array(embedding)
flattended_feature = embedding_np.flatten()

print(flattended_feature)
# Out:
# 1/1 [==============================] - 1s 594ms/step
# [0.         0.         0.19668825 ... 0.         0.         0.        ]

# %%
flattended_feature
# Out:
# array([0.        , 0.        , 0.19668825, ..., 0.        , 0.        ,
#        0.        ], dtype=float32)
